# %% [markdown]
# Unlike the a priori method, the ECLAT method is not based on the calculation of confidence and lift, therefore the ECLAT method is based on the calculation of the support conjunctions of the variables
#
# https://pypi.org/project/pyECLAT/

# %%
import pandas as pd
import ast

# %%
dataset = pd.read_csv("Retail_Transactions_Dataset.csv")

dataset.head()
# Out:
#    Transaction_ID                 Date      Customer_Name  \
# 0      1000000000  2022-01-21 06:27:29       Stacey Price
# 1      1000000001  2023-03-01 13:01:21   Michelle Carlson
# 2      1000000002  2024-03-21 15:37:04        Lisa Graves
# 3      1000000003  2020-10-31 09:59:47  Mrs. Patricia May
# 4      1000000004  2020-12-10 00:59:59     Susan Mitchell
#
#                                              Product  Total_Items  Total_Cost  \
# 0        ['Ketchup', 'Shaving Cream', 'Light Bulbs']            3       71.65
# 1  ['Ice Cream', 'Milk', 'Olive Oil', 'Bread', 'P...            2       25.93
# 2                                        ['Spinach']            6       41.49
# 3                             ['Tissues', 'Mustard']            1       39.34
# 4                                      ['Dish Soap']           10       16.42
#
#    Payment_Method           City        Store_Type  Discount_Applied  \
# 0  Mobile Payment    Los Angeles    Warehouse Club              True
# 1            Cash  San Francisco   Specialty Store              True
# 2     Credit Card        Houston  Department Store              True
# 3  Mobile Payment        Chicago          Pharmacy              True
# 4      Debit Card        Houston   Specialty Store             False
#
#   Customer_Category  Season                   Promotion
# 0         Homemaker  Winter                         NaN
# 1      Professional    Fall      BOGO (Buy One Get One)
# 2      Professional  Winter                         NaN
# 3         Homemaker  Spring                         NaN
# 4       Young Adult  Winter  Discount on Selected Items

# %%
product_list = dataset["Product"].apply(ast.literal_eval).tolist()

products_dataframe = pd.DataFrame(product_list)

products_dataframe
# Out:
#                  0              1              2        3          4
# 0          Ketchup  Shaving Cream    Light Bulbs      NaN        NaN
# 1        Ice Cream           Milk      Olive Oil    Bread   Potatoes
# 2          Spinach            NaN            NaN      NaN        NaN
# 3          Tissues        Mustard            NaN      NaN        NaN
# 4        Dish Soap            NaN            NaN      NaN        NaN
# ...            ...            ...            ...      ...        ...
# 999995     Pickles        Carrots  Peanut Butter  Sponges  BBQ Sauce
# 999996      Cereal            NaN            NaN      NaN        NaN
# 999997  Trash Bags            NaN            NaN      NaN        NaN
# 999998     Diapers         Coffee         Coffee      Mop        NaN
# 999999  Trash Cans            Mop            Jam      NaN        NaN
#
# [1000000 rows x 5 columns]

# %%
from pyECLAT import ECLAT

eclat_instance = ECLAT(data=products_dataframe,
                       verbose=True)  #verbose=True to see the loading bar
# Out:
# 100%|██████████| 81/81 [00:48<00:00,  1.68it/s]
# 100%|██████████| 81/81 [00:01<00:00, 46.25it/s]
# 100%|██████████| 81/81 [00:00<00:00, 264.02it/s]

# %%
eclat_instance.df_bin  #generate a binary dataframe, that can be used for other analyzes.
eclat_instance.uniq_  #a list with all the names of the different items
# Out:
# ['Carrots',
#  'Diapers',
#  'Plant Fertilizer',
#  'Toilet Paper',
#  'Pancake Mix',
#  'Extension Cords',
#  'Shower Gel',
#  'Trash Cans',
#  'Baby Wipes',
#  'Banana',
#  'Dish Soap',
#  'Mayonnaise',
#  'Cleaning Spray',
#  'Power Strips',
#  'Coffee',
#  'Deodorant',
#  'Mop',
#  'Olive Oil',
#  'Shampoo',
#  'Hair Gel',
#  'Dustpan',
#  'Toothbrush',
#  'Mustard',
#  'Syrup',
#  'Lawn Mower',
#  nan,
#  'Tea',
#  'Soap',
#  'Tuna',
#  'Salmon',
#  'Broom',
#  'Garden Hose',
#  'Bath Towels',
#  'Pasta',
#  'Orange',
#  'Shrimp',
#  'Iron',
#  'BBQ Sauce',
#  'Beef',
#  'Hand Sanitizer',
#  'Trash Bags',
#  'Milk',
#  'Bread',
#  'Peanut Butter',
#  'Jam',
#  'Toothpaste',
#  'Tissues',
#  'Shaving Cream',
#  'Dishware',
#  'Light Bulbs',
#  'Chips',
#  'Spinach',
#  'Laundry Detergent',
#  'Cereal',
#  'Onions',
#  'Eggs',
#  'Cheese',
#  'Ketchup',
#  'Canned Soup',
#  'Air Freshener',
#  'Apple',
#  'Chicken',
#  'Ice Cream',
#  'Cleaning Rags',
#  'Tomatoes',
#  'Vacuum Cleaner',
#  'Cereal Bars',
#  'Potatoes',
#  'Razors',
#  'Paper Towels',
#  'Pickles',
#  'Yogurt',
#  'Soda',
#  'Insect Repellent',
#  'Sponges',
#  'Rice',
#  'Feminine Hygiene Products',
#  'Vinegar',
#  'Water',
#  'Honey',
#  'Butter',
#  'Ironing Board']

# %%
get_ECLAT_indexes, get_ECLAT_supports = eclat_instance.fit(min_support=0.03,
                                                           min_combination=2,
                                                           max_combination=2,
                                                           separator=' & ',
                                                           verbose=True)
# Out:
# Combination 2 by 2
# 3240it [00:36, 89.34it/s]

# %%
get_ECLAT_supports
# Out:
# {}
